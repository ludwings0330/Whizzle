# %%
import pandas as pd
import os

# %%
data = pd.read_csv(os.getcwd()+"\\dataset\\whisky_basic\\save_1_600.csv", index_col = 0)

# %%
meta_data = pd.read_csv(os.getcwd()+"\\dataset\\whisky_metadata\\metadata_0_700.csv", index_col = 0)

# %%
data
# Out:
#                                                    link  \
# 0                               /spirits/hibiki-21-year
# 1                             /spirits/highland-park-18
# 2     /spirits/michter-s-20-year-kentucky-straight-b...
# 3             /spirits/george-t-stagg-bourbon-fall-2019
# 4                 /spirits/bowmore-mizunara-cask-finish
# ...                                                 ...
# 3652              /spirits/westland-single-cask-no-1766
# 3653  /spirits/barrell-whiskey-infinite-barrel-proje...
# 3654       /spirits/fercullen-single-malt-aged-20-years
# 3655  /spirits/knob-creek-single-barrel-liquor-barn-...
# 3656       /spirits/knob-creek-single-barrel-fred-noe-6
#
#                                                   image  \
# 0     https://ip-distiller.imgix.net/images/spirits/...
# 1     https://ip-distiller.imgix.net/images/spirits/...
# 2     https://ip-distiller.imgix.net/images/spirits/...
# 3     https://ip-distiller.imgix.net/images/spirits/...
# ...

# %%
meta_data
# Out:
#                                                   name  total_rating  \
# 0                                       Hibiki 21 Year           861
# 1                                Highland Park 18 Year          2987
# 2    Michter's 20 Year Kentucky Straight Bourbon (2...            10
# 3                  George T. Stagg Bourbon (Fall 2019)           628
# 4                         Bowmore Mizunara Cask Finish            22
# ..                                                 ...           ...
# 695                             Port Charlotte 10 Year          1163
# 696          Compass Box Flaming Heart (Sixth Edition)            50
# 697     Booker's Bourbon Batch 2018-03 "Kentucky Chew"           199
# 698           Highland Park Wings of the Eagle 16 Year            50
# 699  Old Fitzgerald Bottled in Bond 9 Year (Fall 2018)           174
#
#      cost_rank    abv                                          cask_type  \
# ...

# %%
meta_700 = pd.read_csv(os.getcwd()+"\\dataset\\whisky_metadata\\metadata_700_1400.csv", index_col=0)
meta_1400 = pd.read_csv(os.getcwd()+"\\dataset\\whisky_metadata\\metadata_1400_2100.csv", index_col=0)
meta_2100 = pd.read_csv(os.getcwd()+"\\dataset\\whisky_metadata\\metadata_2100_2800.csv", index_col=0)
meta_2800 = pd.read_csv(os.getcwd()+"\\dataset\\whisky_metadata\\metadata_2800_3535.csv", index_col=0)

# %%
meta_data = pd.concat([meta_data, meta_700, meta_1400, meta_2100, meta_2800])

# %%
meta_data
# Out:
#                                                    name  total_rating  \
# 0                                        Hibiki 21 Year           861
# 1                                 Highland Park 18 Year          2987
# 2     Michter's 20 Year Kentucky Straight Bourbon (2...            10
# 3                   George T. Stagg Bourbon (Fall 2019)           628
# 4                          Bowmore Mizunara Cask Finish            22
# ...                                                 ...           ...
# 3530                                 Wild Turkey Spiced            13
# 3531         Seagram's 7 Crown American Blended Whiskey           237
# 3532                       11 Wells Single Malt Whiskey             2
# 3533                     Immortal Spirits Early Whiskey             1
# 3534                       Triple Crown Blended Whiskey            16
#
#       cost_rank    abv                                          cask_type  \
# ...

# %% [markdown]
# ### total review count = 907948

# %%
meta_data['total_rating'].sum()
# Out:
# 907948

# %% [markdown]
# ### Meta Data Summary

# %%
meta_data.describe()
# Out:
#        total_rating    cost_rank          abv        smoky        peaty  \
# count   3535.000000  3535.000000  3532.000000  3535.000000  3535.000000
# mean     256.845262     3.141160    47.507081    22.308911     8.764356
# std      821.089471     1.137736     6.462823    20.543387    19.420631
# min        0.000000     1.000000     0.000000     0.000000     0.000000
# 25%       12.000000     2.000000    43.000000     5.000000     0.000000
# 50%       44.000000     3.000000    46.000000    20.000000     0.000000
# 75%      152.000000     4.000000    50.000000    30.000000     0.000000
# max    12255.000000     5.000000    80.000000   100.000000   100.000000
#
#              spicy       herbal         oily  full_bodied         rich  \
# count  3535.000000  3535.000000  3535.000000  3535.000000  3535.000000
# mean     45.916549    26.206789    28.588119    54.667327    54.431966
# std      20.427383    19.450020    19.680687    18.616834    19.170765
# ...

# %%
meta_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3535 entries, 0 to 3534
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          3535 non-null   object
#  1   total_rating  3535 non-null   int64
#  2   cost_rank     3535 non-null   int64
#  3   abv           3532 non-null   float64
#  4   cask_type     2981 non-null   object
#  5   smoky         3535 non-null   int64
#  6   peaty         3535 non-null   int64
#  7   spicy         3535 non-null   int64
#  8   herbal        3535 non-null   int64
#  9   oily          3535 non-null   int64
#  10  full_bodied   3535 non-null   int64
#  11  rich          3535 non-null   int64
#  12  sweet         3535 non-null   int64
#  13  briny         3535 non-null   int64
#  14  salty         3535 non-null   int64
#  15  vanilla       3535 non-null   int64
#  16  tart          3535 non-null   int64
#  17  fruity        3535 non-null   int64
# ...

# %%
meta_data.loc[meta_data["abv"].isnull()]
# Out:
#                                             name  total_rating  cost_rank  \
# 1686    WhistlePig The Boss Hog IX: Siren's Song            11          5
# 2987                 Onyx Moonshine Secret Stash             6          3
# 3172  Double Diamond Limited Edition Bourbon 267             1          2
#
#       abv                                          cask_type  smoky  peaty  \
# 1686  NaN  American oak; finished in Greek fig nectar and...     40      0
# 2987  NaN  5 gallon new, charred American oak sealed in o...     10      0
# 3172  NaN                                       American Oak      0      0
#
#       spicy  herbal  oily  full_bodied  rich  sweet  briny  salty  vanilla  \
# 1686     85      25    20           65    65     45      0      0       20
# 2987     20       0    30           50    40     30      0      0       30
# 3172     30       0    30           20    20     40      0      0       50
#
#       tart  fruity  floral
# 1686    25      55      25
# ...

# %% [markdown]
# 1686 => 51.7

# %% [markdown]
# ### 도수가 null인 위스키 3개
# ---
# - 직접 검색하여 입력해줬습니다.

# %%
meta_data.loc[1686, 'abv'] = 51.7
meta_data.loc[2987, 'abv'] = 45.00
meta_data.loc[3172, 'abv'] = 40.00

# %% [markdown]
# ## Whisky 기본 Data + Meta Data 작업 수행
#
# 0~3534 까지의 위스키 정보 사용
# - 즉, 3535개의 Unique한 위스키가 존재합니다.

# %%
processed_data = pd.merge(data, meta_data)
processed_data
# Out:
#                                                    link  \
# 0                               /spirits/hibiki-21-year
# 1                             /spirits/highland-park-18
# 2     /spirits/michter-s-20-year-kentucky-straight-b...
# 3             /spirits/george-t-stagg-bourbon-fall-2019
# 4                 /spirits/bowmore-mizunara-cask-finish
# ...                                                 ...
# 3530                        /spirits/wild-turkey-spiced
# 3531  /spirits/seagram-s-seven-crown-american-blende...
# 3532              /spirits/11-wells-single-malt-whiskey
# 3533            /spirits/immortal-spirits-early-whiskey
# 3534              /spirits/triple-crown-blended-whiskey
#
#                                                   image  \
# 0     https://ip-distiller.imgix.net/images/spirits/...
# 1     https://ip-distiller.imgix.net/images/spirits/...
# 2     https://ip-distiller.imgix.net/images/spirits/...
# 3     https://ip-distiller.imgix.net/images/spirits/...
# ...

# %%
print("Total Rating Dataset Size : {} ".format(processed_data['total_rating'].sum()))
print()
processed_data.info()
# Out:
# Total Rating Dataset Size : 907948
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3535 entries, 0 to 3534
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   link          3535 non-null   object
#  1   image         3535 non-null   object
#  2   name          3535 non-null   object
#  3   avr_rating    3464 non-null   float64
#  4   category      3535 non-null   object
#  5   location      3535 non-null   object
#  6   total_rating  3535 non-null   int64
#  7   cost_rank     3535 non-null   int64
#  8   abv           3535 non-null   float64
#  9   cask_type     2981 non-null   object
#  10  smoky         3535 non-null   int64
#  11  peaty         3535 non-null   int64
#  12  spicy         3535 non-null   int64
#  13  herbal        3535 non-null   int64
#  14  oily          3535 non-null   int64
#  15  full_bodied   3535 non-null   int64
#  16  rich          3535 non-null   int64
# ...

# %% [markdown]
# ## 위스키 데이터 완성

# %%
savePath = os.getcwd()+"\\dataset"
processed_data.to_csv(savePath+"\\whisky.csv")
